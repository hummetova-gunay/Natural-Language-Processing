# %% [markdown]
# # Sentiment analysis with Transformers
# In traditional NLP techniques section we used Vader library, here we are going to use `Distilbert` - variation of BERT (base model), lighter with fewer parameters - therefore runs faster

# %%
import pandas as pd

# %%
df= pd.read_excel('Popchip_Reviews_Sentiment.xlsx')
df.head(2)
# Out:
#       Id          UserId  Rating Priority  \
# 0  23689  A21SYVGVNG8RAS       5      Low
# 1  23690   AQJYXC0MPRQJL       5      Low
#
#                                         Title  \
# 0                               Yummy snacks!
# 1  Great chip that is different from the rest
#
#                                                 Text  Sentiment_VADER
# 0  Popchips are the bomb!!  I use the parmesan ga...           0.9244
# 1  I like the puffed nature of this chip that mak...           0.7269

# %%
# to run the code faster, just take 30 rows of data
df = pd.read_excel('Popchip_Reviews_Sentiment.xlsx').head(30)
df.head(2)
# Out:
#       Id          UserId  Rating Priority  \
# 0  23689  A21SYVGVNG8RAS       5      Low
# 1  23690   AQJYXC0MPRQJL       5      Low
#
#                                         Title  \
# 0                               Yummy snacks!
# 1  Great chip that is different from the rest
#
#                                                 Text  Sentiment_VADER
# 0  Popchips are the bomb!!  I use the parmesan ga...           0.9244
# 1  I like the puffed nature of this chip that mak...           0.7269

# %% [markdown]
# ## Sentiment Analysis

# %%
from transformers import pipeline

# %%
import sys
# !{sys.executable} -m pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.57.3-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: filelock in c:\users\ghummatova\appdata\local\anaconda3\lib\site-packages (from transformers) (3.17.0)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers)
#   Using cached huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\ghummatova\appdata\local\anaconda3\lib\site-packages (from transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\ghummatova\appdata\roaming\python\python313\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ghummatova\appdata\local\anaconda3\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\ghummatova\appdata\local\anaconda3\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\ghummatova\appdata\local\anaconda3\lib\site-packages (from transformers) (2.32.3)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading tokenizers-0.22.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\ghummatova\appdata\local\anaconda3\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ghummatova\appdata\local\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ghummatova\appdata\local\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.12.2)
# Requirement already satisfied: colorama in c:\users\ghummatova\appdata\roaming\python\python313\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ghummatova\appdata\local\anaconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ghummatova\appdata\local\anaconda3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ghummatova\appdata\local\anaconda3\lib\site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ghummatova\appdata\local\anaconda3\lib\site-packages (from requests->transformers) (2025.4.26)
# Downloading transformers-4.57.3-py3-none-any.whl (12.0 MB)
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.0 MB 2.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.3/12.0 MB 2.6 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/12.0 MB 2.7 MB/s eta 0:00:04
#    ------- -------------------------------- 2.4/12.0 MB 2.8 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.4/12.0 MB 3.1 MB/s eta 0:00:03
#    ------------- -------------------------- 4.2/12.0 MB 3.2 MB/s eta 0:00:03
#    ---------------- ----------------------- 5.0/12.0 MB 3.3 MB/s eta 0:00:03
#    ------------------ --------------------- 5.5/12.0 MB 3.3 MB/s eta 0:00:02
#    -------------------- ------------------- 6.3/12.0 MB 3.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.1/12.0 MB 3.3 MB/s eta 0:00:02
#    -------------------------- ------------- 7.9/12.0 MB 3.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.9/12.0 MB 3.5 MB/s eta 0:00:01
#    -------------------------------- ------- 9.7/12.0 MB 3.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.7/12.0 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  11.8/12.0 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.0/12.0 MB 3.5 MB/s eta 0:00:00
# Using cached huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
# Downloading tokenizers-0.22.1-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ----------- ---------------------------- 0.8/2.7 MB 4.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.6/2.7 MB 4.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.7 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 3.9 MB/s eta 0:00:00
# Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
#
#    ---------------------------------------- 0/4 [safetensors]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    ---------- ----------------------------- 1/4 [huggingface-hub]
#    -------------------- ------------------- 2/4 [tokenizers]
#    -------------------- ------------------- 2/4 [tokenizers]
#    -------------------- ------------------- 2/4 [tokenizers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ------------------------------ --------- 3/4 [transformers]
#    ---------------------------------------- 4/4 [transformers]
#
# Successfully installed huggingface-hub-0.36.0 safetensors-0.7.0 tokenizers-0.22.1 transformers-4.57.3

# %%
from transformers import pipeline
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %%
import sys
# !{sys.executable} -m pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\ghummatova\appdata\local\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: filelock in c:\users\ghummatova\appdata\local\anaconda3\lib\site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\ghummatova\appdata\local\anaconda3\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\ghummatova\appdata\local\anaconda3\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\ghummatova\appdata\local\anaconda3\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\ghummatova\appdata\local\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\ghummatova\appdata\local\anaconda3\lib\site-packages (from torch) (2025.3.2)
# Requirement already satisfied: setuptools in c:\users\ghummatova\appdata\local\anaconda3\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ghummatova\appdata\local\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ghummatova\appdata\local\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)

# %%
sentiment_analyzer = pipeline('sentiment-analysis', model = 'distilbert/distilbert-base-uncased-finetuned-sst-2-english', device =-1)
# Out:
# Device set to use cpu

# %%
text1 = 'When life gives you lemons, make lemonade!'
text2 = 'A dozen lemons will make a gallon of lemonade.'
text3 = 'I didn\'t like the taste of that lemonade at all'

# %%
sentiment_analyzer(text1)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9983568787574768}]

# %%
sentiment_analyzer(text2)
# Out:
# [{'label': 'POSITIVE', 'score': 0.7781569361686707}]

# %%
sentiment_analyzer(text3)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.995613694190979}]

# %%
# apply to the dataset
df.Text.apply(sentiment_analyzer)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (668 > 512). Running this sequence through the model will result in indexing errors
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 2
#       1 # apply to the dataset
# ----> 2 df.Text.apply(sentiment_analyzer)
#
# File c:\Users\ghummatova\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)   4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)   4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\ghummatova\AppData\Local\anaconda3\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\ghummatova\AppData\Local\anaconda3\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\ghummatova\AppData\Local\anaconda3\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\ghummatova\AppData\Local\anaconda3\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# File c:\Users\ghummatova\AppData\Local\anaconda3\Lib\site-packages\transformers\pipelines\text_classification.py:168, in TextClassificationPipeline.__call__(self, inputs, **kwargs)
#     133 """
#     134 Classify the text(s) given as inputs.
#     135
#    (...)    165     If `top_k` is used, one such dictionary is returned per label.
#     166 """
#     167 inputs = (inputs,)
# --> 168 result = super().__call__(*inputs, **kwargs)
#     169 # TODO try and retrieve it in a nicer way from _sanitize_parameters.
#     170 _legacy = "top_k" not in kwargs
#
# File c:\Users\ghummatova\AppData\Local\anaconda3\Lib\site-packages\transformers\pipelines\base.py:1467, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1459     return next(
#    1460         iter(
#    1461             self.get_iterator(
#    (...)   1464         )
#    1465     )
#    1466 else:
# -> 1467     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File c:\Users\ghummatova\AppData\Local\anaconda3\Lib\site-packages\transformers\pipelines\base.py:1474, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1472 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1473     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1474     model_outputs = self.forward(model_inputs, **forward_params)
#    1475     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1476     return outputs
#
# File c:\Users\ghummatova\AppData\Local\anaconda3\Lib\site-packages\transformers\pipelines\base.py:1374, in Pipeline.forward(self, model_inputs, **forward_params)
#    1372     with inference_context():
#    1373         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1374         model_outputs = self._forward(model_inputs, **forward_params)
#    1375         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1376 else:
#
# File c:\Users\ghummatova\AppData\Local\anaconda3\Lib\site-packages\transformers\pipelines\text_classification.py:199, in TextClassificationPipeline._forward(self, model_inputs)
#     197 if "use_cache" in inspect.signature(model_forward).parameters:
#     198     model_inputs["use_cache"] = False
# --> 199 return self.model(**model_inputs)
#
# File c:\Users\ghummatova\AppData\Local\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ghummatova\AppData\Local\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\ghummatova\AppData\Local\anaconda3\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:905, in DistilBertForSequenceClassification.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#     897 r"""
#     898 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#     899     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#     900     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#     901     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#     902 """
#     903 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 905 distilbert_output = self.distilbert(
#     906     input_ids=input_ids,
#     907     attention_mask=attention_mask,
#     908     head_mask=head_mask,
#     909     inputs_embeds=inputs_embeds,
#     910     output_attentions=output_attentions,
#     911     output_hidden_states=output_hidden_states,
#     912     return_dict=return_dict,
#     913 )
#     914 hidden_state = distilbert_output[0]  # (bs, seq_len, dim)
#     915 pooled_output = hidden_state[:, 0]  # (bs, dim)
#
# File c:\Users\ghummatova\AppData\Local\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ghummatova\AppData\Local\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\ghummatova\AppData\Local\anaconda3\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:711, in DistilBertModel.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     708 # Prepare head mask if needed
#     709 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# --> 711 embeddings = self.embeddings(input_ids, inputs_embeds)  # (bs, seq_length, dim)
#     713 if self.config._attn_implementation == "flash_attention_2":
#     714     attention_mask = attention_mask if (attention_mask is not None and 0 in attention_mask) else None
#
# File c:\Users\ghummatova\AppData\Local\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\ghummatova\AppData\Local\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\ghummatova\AppData\Local\anaconda3\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:125, in Embeddings.forward(self, input_ids, input_embeds)
#     121     position_ids = position_ids.unsqueeze(0).expand_as(input_ids)  # (bs, max_seq_length)
#     123 position_embeddings = self.position_embeddings(position_ids)  # (bs, max_seq_length, dim)
# --> 125 embeddings = input_embeds + position_embeddings  # (bs, max_seq_length, dim)
#     126 embeddings = self.LayerNorm(embeddings)  # (bs, max_seq_length, dim)
#     127 embeddings = self.dropout(embeddings)  # (bs, max_seq_length, dim)
#
# RuntimeError: The size of tensor a (668) must match the size of tensor b (512) at non-singleton dimension 1

# %% [markdown]
# within the dataset, there is a review that has 668 tokens (>512 that the model can handle). To resolve this we need to make the text shorter by setting `truncation=True`

# %%
sentiment_analyzer = pipeline('sentiment-analysis', model = 'distilbert/distilbert-base-uncased-finetuned-sst-2-english', device =-1, truncation =True)
# Out:
# Device set to use cpu

# %%
df.Text.apply(sentiment_analyzer)
# Out:
# 0     [{'label': 'POSITIVE', 'score': 0.993521273136...
# 1     [{'label': 'POSITIVE', 'score': 0.999605119228...
# 2     [{'label': 'NEGATIVE', 'score': 0.698487639427...
# 3     [{'label': 'NEGATIVE', 'score': 0.999630808830...
# 4     [{'label': 'POSITIVE', 'score': 0.999181449413...
# 5     [{'label': 'POSITIVE', 'score': 0.999419689178...
# 6     [{'label': 'POSITIVE', 'score': 0.999218821525...
# 7     [{'label': 'POSITIVE', 'score': 0.996904075145...
# 8     [{'label': 'POSITIVE', 'score': 0.989402770996...
# 9     [{'label': 'POSITIVE', 'score': 0.999183237552...
# 10    [{'label': 'POSITIVE', 'score': 0.999485135078...
# 11    [{'label': 'NEGATIVE', 'score': 0.725596308708...
# 12    [{'label': 'POSITIVE', 'score': 0.996617376804...
# 13    [{'label': 'POSITIVE', 'score': 0.999719560146...
# 14    [{'label': 'POSITIVE', 'score': 0.894436717033...
# 15    [{'label': 'POSITIVE', 'score': 0.998936831951...
# 16    [{'label': 'POSITIVE', 'score': 0.999853491783...
# 17    [{'label': 'POSITIVE', 'score': 0.966337740421...
# 18    [{'label': 'NEGATIVE', 'score': 0.942053198814...
# 19    [{'label': 'POSITIVE', 'score': 0.999761164188...
# 20    [{'label': 'NEGATIVE', 'score': 0.965379357337...
# 21    [{'label': 'POSITIVE', 'score': 0.945945858955...
# 22    [{'label': 'POSITIVE', 'score': 0.998185098171...
# 23    [{'label': 'POSITIVE', 'score': 0.999003827571...
# 24    [{'label': 'NEGATIVE', 'score': 0.752333283424...
# 25    [{'label': 'POSITIVE', 'score': 0.999221563339...
# 26    [{'label': 'NEGATIVE', 'score': 0.990390181541...
# 27    [{'label': 'POSITIVE', 'score': 0.999483942985...
# 28    [{'label': 'POSITIVE', 'score': 0.999873638153...
# 29    [{'label': 'NEGATIVE', 'score': 0.930706560611...
# Name: Text, dtype: object

# %% [markdown]
# ### Sentiment analysis - round 2, but faster, nicer, better

# %%
import torch as t

# %%
from transformers import logging
logging.set_verbosity_error() # only see errors not warnings
# Automatically select the best device (GPU) available
device = 0 if t.cuda.is_available() else -1  # 0 for GPU, -1 for CPU

sentiment_analyzer =pipeline('sentiment-analysis', model = 'distilbert/distilbert-base-uncased-finetuned-sst-2-english',
                            device = device,
                            truncation = True)
df.Text.apply(sentiment_analyzer)
# Out:
# 0     [{'label': 'POSITIVE', 'score': 0.993521273136...
# 1     [{'label': 'POSITIVE', 'score': 0.999605119228...
# 2     [{'label': 'NEGATIVE', 'score': 0.698487639427...
# 3     [{'label': 'NEGATIVE', 'score': 0.999630808830...
# 4     [{'label': 'POSITIVE', 'score': 0.999181449413...
# 5     [{'label': 'POSITIVE', 'score': 0.999419689178...
# 6     [{'label': 'POSITIVE', 'score': 0.999218821525...
# 7     [{'label': 'POSITIVE', 'score': 0.996904075145...
# 8     [{'label': 'POSITIVE', 'score': 0.989402770996...
# 9     [{'label': 'POSITIVE', 'score': 0.999183237552...
# 10    [{'label': 'POSITIVE', 'score': 0.999485135078...
# 11    [{'label': 'NEGATIVE', 'score': 0.725596308708...
# 12    [{'label': 'POSITIVE', 'score': 0.996617376804...
# 13    [{'label': 'POSITIVE', 'score': 0.999719560146...
# 14    [{'label': 'POSITIVE', 'score': 0.894436717033...
# 15    [{'label': 'POSITIVE', 'score': 0.998936831951...
# 16    [{'label': 'POSITIVE', 'score': 0.999853491783...
# 17    [{'label': 'POSITIVE', 'score': 0.966337740421...
# 18    [{'label': 'NEGATIVE', 'score': 0.942053198814...
# 19    [{'label': 'POSITIVE', 'score': 0.999761164188...
# 20    [{'label': 'NEGATIVE', 'score': 0.965379357337...
# 21    [{'label': 'POSITIVE', 'score': 0.945945858955...
# 22    [{'label': 'POSITIVE', 'score': 0.998185098171...
# 23    [{'label': 'POSITIVE', 'score': 0.999003827571...
# 24    [{'label': 'NEGATIVE', 'score': 0.752333283424...
# 25    [{'label': 'POSITIVE', 'score': 0.999221563339...
# 26    [{'label': 'NEGATIVE', 'score': 0.990390181541...
# 27    [{'label': 'POSITIVE', 'score': 0.999483942985...
# 28    [{'label': 'POSITIVE', 'score': 0.999873638153...
# 29    [{'label': 'NEGATIVE', 'score': 0.930706560611...
# Name: Text, dtype: object

# %% [markdown]
# # Clean up the output

# %%
pd.set_option('display.max_colwidth', None)

# %%
sentiment_scores= df.Text.apply(sentiment_analyzer)
sentiment_scores[:5]
# Out:
# 0    [{'label': 'POSITIVE', 'score': 0.9935212731361389}]
# 1     [{'label': 'POSITIVE', 'score': 0.999605119228363}]
# 2    [{'label': 'NEGATIVE', 'score': 0.6984876394271851}]
# 3    [{'label': 'NEGATIVE', 'score': 0.9996308088302612}]
# 4    [{'label': 'POSITIVE', 'score': 0.9991814494132996}]
# Name: Text, dtype: object

# %%
sentiment_scores[0][0]['label']
# Out:
# 'POSITIVE'

# %%
sentiment_scores[0][0]['score']
# Out:
# 0.9935212731361389

# %%
# create a new column in the dataframe that has all the labels
# for that you need to extract all the labels from sentiment scores 
# sentiment_scores is series
# use lambda function to extract labels 
sentiment_scores.apply(lambda x: x[0]['label'])
# x is an input, in our case it is every row, every row is a list, 0th item in every list is a dictionary and we want 'label' key in these dictionaries
# Out:
# 0     POSITIVE
# 1     POSITIVE
# 2     NEGATIVE
# 3     NEGATIVE
# 4     POSITIVE
# 5     POSITIVE
# 6     POSITIVE
# 7     POSITIVE
# 8     POSITIVE
# 9     POSITIVE
# 10    POSITIVE
# 11    NEGATIVE
# 12    POSITIVE
# 13    POSITIVE
# 14    POSITIVE
# 15    POSITIVE
# 16    POSITIVE
# 17    POSITIVE
# 18    NEGATIVE
# 19    POSITIVE
# 20    NEGATIVE
# 21    POSITIVE
# 22    POSITIVE
# 23    POSITIVE
# 24    NEGATIVE
# 25    POSITIVE
# 26    NEGATIVE
# 27    POSITIVE
# 28    POSITIVE
# 29    NEGATIVE
# Name: Text, dtype: object

# %%
# save this output as a new column in the dataset
df['Label_HF'] = sentiment_scores.apply(lambda x: x[0]['label'])
df.head(3)
# Out:
#       Id          UserId  Rating Priority  \
# 0  23689  A21SYVGVNG8RAS       5      Low
# 1  23690   AQJYXC0MPRQJL       5      Low
# 2  23691  A30NYUHEDLWI0Y       5     High
#
#                                         Title  \
# 0                               Yummy snacks!
# 1  Great chip that is different from the rest
# 2          Great  Alternative to Potato Chips
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Text  \
# 0                                                                                                                                                                                                                                                                                                                                                                                     Popchips are the bomb!!  I use the parmesan garlic to scoop up cottage cheese as a healthy alternative to chips and dip.  My healthy eating program is saved.
# 1  I like the puffed nature of this chip that makes it more unique in the chip market.  I ordered the Salt and Vinegar and absolutely love that flavor, hands down my favorite chip ever.  I have tried the cheddar and regular flavors as well.  The cheddar is about a 4/5 and the regular is about a 3/5 because I prefer strong flavors and obviously that would not be the case for the regular.  The Salt and Vinegar is kind of weak compared to some regular S&V chips, but is quite flavorful and makes you wanting to come back for more.
# 2                                                                        I just love these chips!  I was always a big fan of potato chips, but haven't had one since I discovered popchips.  They are great for dipping or all alone.  I am constantly re-ordering them.  One note however-if you are on a low salt diet these chips are probably not for you. They are high in sodium.  We go through a case every two months.  If you love them it pays to join the subscribe and save program through Amazon.  You save money and stay supplied!
#
#    Sentiment_VADER  Label_HF
# 0           0.9244  POSITIVE
# 1           0.7269  POSITIVE
# 2           0.9790  NEGATIVE

# %%
df['Score_HF'] = sentiment_scores.apply(lambda x : x[0]['score'])
df.head(2)
# Out:
#       Id          UserId  Rating Priority  \
# 0  23689  A21SYVGVNG8RAS       5      Low
# 1  23690   AQJYXC0MPRQJL       5      Low
#
#                                         Title  \
# 0                               Yummy snacks!
# 1  Great chip that is different from the rest
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Text  \
# 0                                                                                                                                                                                                                                                                                                                                                                                     Popchips are the bomb!!  I use the parmesan garlic to scoop up cottage cheese as a healthy alternative to chips and dip.  My healthy eating program is saved.
# 1  I like the puffed nature of this chip that makes it more unique in the chip market.  I ordered the Salt and Vinegar and absolutely love that flavor, hands down my favorite chip ever.  I have tried the cheddar and regular flavors as well.  The cheddar is about a 4/5 and the regular is about a 3/5 because I prefer strong flavors and obviously that would not be the case for the regular.  The Salt and Vinegar is kind of weak compared to some regular S&V chips, but is quite flavorful and makes you wanting to come back for more.
#
#    Sentiment_VADER  Label_HF  Score_HF
# 0           0.9244  POSITIVE  0.993521
# 1           0.7269  POSITIVE  0.999605

# %%
# change the score column, if the label is positive keep the score as it is, otherwise return negative version of the score
df.apply(lambda row: row['Score_HF'] if row['Label_HF']=='POSITIVE' else -row['Score_HF'], axis =1)
# Out:
# 0     0.993521
# 1     0.999605
# 2    -0.698488
# 3    -0.999631
# 4     0.999181
# 5     0.999420
# 6     0.999219
# 7     0.996904
# 8     0.989403
# 9     0.999183
# 10    0.999485
# 11   -0.725596
# 12    0.996617
# 13    0.999720
# 14    0.894437
# 15    0.998937
# 16    0.999853
# 17    0.966338
# 18   -0.942053
# 19    0.999761
# 20   -0.965379
# 21    0.945946
# 22    0.998185
# 23    0.999004
# 24   -0.752333
# 25    0.999222
# 26   -0.990390
# 27    0.999484
# 28    0.999874
# 29   -0.930707
# dtype: float64

# %%
# create a new column for this
df['Sentiment_HF'] = df.apply(lambda row: row['Score_HF'] if row['Label_HF']=='POSITIVE' else -row['Score_HF'], axis =1)
df.head(2)
# Out:
#       Id          UserId  Rating Priority  \
# 0  23689  A21SYVGVNG8RAS       5      Low
# 1  23690   AQJYXC0MPRQJL       5      Low
#
#                                         Title  \
# 0                               Yummy snacks!
# 1  Great chip that is different from the rest
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Text  \
# 0                                                                                                                                                                                                                                                                                                                                                                                     Popchips are the bomb!!  I use the parmesan garlic to scoop up cottage cheese as a healthy alternative to chips and dip.  My healthy eating program is saved.
# 1  I like the puffed nature of this chip that makes it more unique in the chip market.  I ordered the Salt and Vinegar and absolutely love that flavor, hands down my favorite chip ever.  I have tried the cheddar and regular flavors as well.  The cheddar is about a 4/5 and the regular is about a 3/5 because I prefer strong flavors and obviously that would not be the case for the regular.  The Salt and Vinegar is kind of weak compared to some regular S&V chips, but is quite flavorful and makes you wanting to come back for more.
#
#    Sentiment_VADER  Label_HF  Score_HF  Sentiment_HF
# 0           0.9244  POSITIVE  0.993521      0.993521
# 1           0.7269  POSITIVE  0.999605      0.999605

# %% [markdown]
# # Speeding up transformers code
# Using GPUs is the fastest way but there are ways to try some techniques to speed up code if we only have GPU available

# %%
from transformers import pipeline
sentiment_analyzer =  pipeline('sentiment_analysis',
                               model = 'distilbert-base-uncased-finetuned-sst-2-english', # 1. smaller model
                               device =-1, # running on CPU
                               truncation=True,
                               use_fast=True # 2. faster tokenization
)
import torch
torch.set_num_threads(1) # 3. specify multi-threading

with torch.no_grad(): # 4. disable gradients
    sentiment_scores = df['Text'].apply(sentiment_analyzer)
