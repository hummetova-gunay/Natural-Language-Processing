# %% [markdown]
# # Divide books into 5 categories:
# 1. Adventure and Fantasy
# 2. Animals and Nature
# 3. Mystery
# 4. Humor
# 5. Non-Fiction
# **Objectives**:
# - apply zero-shot-classification to description column
# - find the number of books in each category and check if they make sense
