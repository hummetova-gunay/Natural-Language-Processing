# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Initialize VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Product comments dataset
product_comments = {
    'Wireless Bluetooth Headphones': [
        "Great sound quality and comfortable to wear for hours!",
        "Battery life is impressive, lasted all day at work",
        "Connection keeps dropping, very frustrating",
        "Perfect for my morning runs, stays in place",
        "A bit pricey but worth it for the noise cancellation"
    ],
    'Coffee Maker': [
        "Brews coffee quickly and tastes great",
        "Leaks water from the bottom, had to return it",
        "Easy to clean and looks nice on my counter",
        "The timer function is super convenient for mornings",
        "Makes coffee too weak, even on strongest setting"
    ],
    'Running Shoes': [
        "Most comfortable shoes I've ever owned!",
        "Great arch support for my flat feet",
        "Sizing runs small, had to exchange for larger size",
        "Wore them on a 10k run, no blisters at all",
        "Started falling apart after just 2 months"
    ],
    'Smartphone Case': [
        "Protective and stylish, love the color options",
        "Too bulky, makes phone hard to fit in pocket",
        "Saved my phone from a nasty fall, highly recommend",
        "Buttons are hard to press through the case",
        "Good value for the price"
    ],
    'Yoga Mat': [
        "Great grip, doesn't slip during poses",
        "Good thickness, comfortable on hardwood floors",
        "Has a strong rubber smell that won't go away",
        "Perfect size and rolls up easily for storage",
        "Material started peeling after a few weeks"
    ]
}

# Analyze sentiment for each product
print("=" * 80)
print("VADER SENTIMENT ANALYSIS - PRODUCT COMMENTS")
print("=" * 80)

for product, comments in product_comments.items():
    print(f"\n📦 PRODUCT: {product}")
    print("-" * 80)
    
    sentiment_counts = {'Positive': 0, 'Neutral': 0, 'Negative': 0}
    total_compound = 0
    
    for i, comment in enumerate(comments, 1):
        # Get sentiment scores
        scores = analyzer.polarity_scores(comment)
        
        # Determine sentiment category
        if scores['compound'] >= 0.05:
            sentiment = 'Positive'
        elif scores['compound'] <= -0.05:
            sentiment = 'Negative'
        else:
            sentiment = 'Neutral'
        
        sentiment_counts[sentiment] += 1
        total_compound += scores['compound']
        
        # Print results
        print(f"\n{i}. \"{comment}\"")
        print(f"   Scores: pos={scores['pos']:.3f}, neu={scores['neu']:.3f}, neg={scores['neg']:.3f}, compound={scores['compound']:.3f}")
        print(f"   Sentiment: {sentiment}")
    
    # Product summary
    avg_compound = total_compound / len(comments)
    print(f"\n📊 SUMMARY:")
    print(f"   Positive: {sentiment_counts['Positive']}, Neutral: {sentiment_counts['Neutral']}, Negative: {sentiment_counts['Negative']}")
    print(f"   Average Compound Score: {avg_compound:.3f}")
    print("-" * 80)

print("\n" + "=" * 80)
print("ANALYSIS COMPLETE")
print("=" * 80)
# Out:
# ================================================================================
# VADER SENTIMENT ANALYSIS - PRODUCT COMMENTS
# ================================================================================
#
# 📦 PRODUCT: Wireless Bluetooth Headphones
# --------------------------------------------------------------------------------
#
# 1. "Great sound quality and comfortable to wear for hours!"
#    Scores: pos=0.524, neu=0.476, neg=0.000, compound=0.827
#    Sentiment: Positive
#
# 2. "Battery life is impressive, lasted all day at work"
#    Scores: pos=0.292, neu=0.708, neg=0.000, compound=0.511
#    Sentiment: Positive
#
# 3. "Connection keeps dropping, very frustrating"
#    Scores: pos=0.000, neu=0.556, neg=0.444, compound=-0.493
#    Sentiment: Negative
#
# 4. "Perfect for my morning runs, stays in place"
#    Scores: pos=0.346, neu=0.654, neg=0.000, compound=0.572
#    Sentiment: Positive
#
# 5. "A bit pricey but worth it for the noise cancellation"
#    Scores: pos=0.207, neu=0.793, neg=0.000, compound=0.329
#    Sentiment: Positive
#
# 📊 SUMMARY:
#    Positive: 4, Neutral: 0, Negative: 1
#    Average Compound Score: 0.349
# --------------------------------------------------------------------------------
#
# 📦 PRODUCT: Coffee Maker
# --------------------------------------------------------------------------------
#
# 1. "Brews coffee quickly and tastes great"
#    Scores: pos=0.451, neu=0.549, neg=0.000, compound=0.625
#    Sentiment: Positive
#
# 2. "Leaks water from the bottom, had to return it"
#    Scores: pos=0.000, neu=1.000, neg=0.000, compound=0.000
#    Sentiment: Neutral
#
# 3. "Easy to clean and looks nice on my counter"
#    Scores: pos=0.583, neu=0.417, neg=0.000, compound=0.813
#    Sentiment: Positive
#
# 4. "The timer function is super convenient for mornings"
#    Scores: pos=0.358, neu=0.642, neg=0.000, compound=0.599
#    Sentiment: Positive
#
# 5. "Makes coffee too weak, even on strongest setting"
#    Scores: pos=0.246, neu=0.508, neg=0.246, compound=0.000
#    Sentiment: Neutral
#
# 📊 SUMMARY:
#    Positive: 3, Neutral: 2, Negative: 0
#    Average Compound Score: 0.407
# --------------------------------------------------------------------------------
#
# 📦 PRODUCT: Running Shoes
# --------------------------------------------------------------------------------
#
# 1. "Most comfortable shoes I've ever owned!"
#    Scores: pos=0.437, neu=0.563, neg=0.000, compound=0.597
#    Sentiment: Positive
#
# 2. "Great arch support for my flat feet"
#    Scores: pos=0.576, neu=0.424, neg=0.000, compound=0.778
#    Sentiment: Positive
#
# 3. "Sizing runs small, had to exchange for larger size"
#    Scores: pos=0.000, neu=1.000, neg=0.000, compound=0.000
#    Sentiment: Neutral
#
# 4. "Wore them on a 10k run, no blisters at all"
#    Scores: pos=0.000, neu=0.804, neg=0.196, compound=-0.296
#    Sentiment: Negative
#
# 5. "Started falling apart after just 2 months"
#    Scores: pos=0.000, neu=0.789, neg=0.211, compound=-0.153
#    Sentiment: Negative
#
# 📊 SUMMARY:
#    Positive: 2, Neutral: 1, Negative: 2
#    Average Compound Score: 0.185
# --------------------------------------------------------------------------------
#
# 📦 PRODUCT: Smartphone Case
# --------------------------------------------------------------------------------
#
# 1. "Protective and stylish, love the color options"
#    Scores: pos=0.412, neu=0.588, neg=0.000, compound=0.637
#    Sentiment: Positive
#
# 2. "Too bulky, makes phone hard to fit in pocket"
#    Scores: pos=0.229, neu=0.642, neg=0.128, compound=0.273
#    Sentiment: Positive
#
# 3. "Saved my phone from a nasty fall, highly recommend"
#    Scores: pos=0.368, neu=0.395, neg=0.237, compound=0.248
#    Sentiment: Positive
#
# 4. "Buttons are hard to press through the case"
#    Scores: pos=0.000, neu=0.833, neg=0.167, compound=-0.103
#    Sentiment: Negative
#
# 5. "Good value for the price"
#    Scores: pos=0.639, neu=0.361, neg=0.000, compound=0.649
#    Sentiment: Positive
#
# 📊 SUMMARY:
#    Positive: 4, Neutral: 0, Negative: 1
#    Average Compound Score: 0.341
# --------------------------------------------------------------------------------
#
# 📦 PRODUCT: Yoga Mat
# --------------------------------------------------------------------------------
#
# 1. "Great grip, doesn't slip during poses"
#    Scores: pos=0.451, neu=0.549, neg=0.000, compound=0.625
#    Sentiment: Positive
#
# 2. "Good thickness, comfortable on hardwood floors"
#    Scores: pos=0.608, neu=0.392, neg=0.000, compound=0.735
#    Sentiment: Positive
#
# 3. "Has a strong rubber smell that won't go away"
#    Scores: pos=0.292, neu=0.708, neg=0.000, compound=0.511
#    Sentiment: Positive
#
# 4. "Perfect size and rolls up easily for storage"
#    Scores: pos=0.504, neu=0.496, neg=0.000, compound=0.727
#    Sentiment: Positive
#
# 5. "Material started peeling after a few weeks"
#    Scores: pos=0.000, neu=1.000, neg=0.000, compound=0.000
#    Sentiment: Neutral
#
# 📊 SUMMARY:
#    Positive: 4, Neutral: 1, Negative: 0
#    Average Compound Score: 0.520
# --------------------------------------------------------------------------------
#
# ================================================================================
# ANALYSIS COMPLETE
# ================================================================================
